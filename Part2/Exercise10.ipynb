# %%
import pandas as pd

# %%
cars = pd.read_csv('cars_raw.csv')

# %%
cars
# Out:
#                                           Welcome    to            the  \
# Feel    free  to         analyze  and       clean   the          messy
# 18.0   8     307.0      130.0 hp 3504        12.0    70  United States
# 15.0   8     350.0      165.0 hp 3693        11.5    70  United States
# 18.0   8     318.0      150.0 hp 3436        11.0    70  United States
# 16.0   8     304.0      150.0 hp 3433        12.0    70            usa
# ...                                           ...   ...            ...
# 27.0   4     101.0      83.0 hp  2202        15.3    76         europe
# 17.0   6     250.0      100.0 hp 3329        15.5    71            usa
# 14.5   8     351.0      152.0 hp 4215        12.8    76            usa
# 25.0   6     181.0      110.0 hp 2945        16.4    82            usa
# Thanks  for   analyzing  this     Dataset       !   NaN            NaN
#
#                                                                    cars  \
# ...

# %%
labels = ['mpg',
 'cylinders',
 'displacement',
 'horsepower',
 'weight',
 'acceleration',
 'model year',
 'origin',
 'name']

# %%
cars.reset_index(inplace=True)

# %%
cars
# Out:
#     level_0 level_1     level_2   level_3   level_4 Welcome    to  \
# 0     Feel     free          to   analyze       and   clean   the
# 1      18.0       8       307.0  130.0 hp      3504    12.0    70
# 2      15.0       8       350.0  165.0 hp      3693    11.5    70
# 3      18.0       8       318.0  150.0 hp      3436    11.0    70
# 4      16.0       8       304.0  150.0 hp      3433    12.0    70
# ..      ...     ...         ...       ...       ...     ...   ...
# 326    27.0       4       101.0   83.0 hp      2202    15.3    76
# 327    17.0       6       250.0  100.0 hp      3329    15.5    71
# 328    14.5       8       351.0  152.0 hp      4215    12.8    76
# 329    25.0       6       181.0  110.0 hp      2945    16.4    82
# 330  Thanks    for    analyzing      this   Dataset       !   NaN
#
#                the                          cars  Dataset!
# 0            messy                       Dataset         !
# ...

# %%
cars.drop(labels=0, axis=0, inplace=True)

# %%
cars.reset_index(inplace=True)

# %%
#cars.columns
cars.drop(labels=['index', ' Dataset!'], axis=1, inplace=True)

# %%
cars.columns = labels

# %%
cars. horsepower = cars.horsepower.str.replace('.0 hp', '')

# %%
cars
# Out:
#         mpg cylinders displacement horsepower    weight acceleration  \
# 0      18.0         8        307.0        130      3504         12.0
# 1      15.0         8        350.0        165      3693         11.5
# 2      18.0         8        318.0        150      3436         11.0
# 3      16.0         8        304.0        150      3433         12.0
# 4      17.0         8        302.0        140      3449         10.5
# ..      ...       ...          ...        ...       ...          ...
# 325    27.0         4        101.0         83      2202         15.3
# 326    17.0         6        250.0        100      3329         15.5
# 327    14.5         8        351.0        152      4215         12.8
# 328    25.0         6        181.0        110      2945         16.4
# 329  Thanks      for     analyzing       this   Dataset            !
#
#     model year         origin                          name
# 0           70  United States    chevrolet chevelle malibu
# ...

# %%
cars.drop(labels=329, axis=0, inplace=True)

# %%
cars
# Out:
#       mpg cylinders displacement horsepower weight acceleration model year  \
# 0    18.0         8        307.0        130   3504         12.0         70
# 1    15.0         8        350.0        165   3693         11.5         70
# 2    18.0         8        318.0        150   3436         11.0         70
# 3    16.0         8        304.0        150   3433         12.0         70
# 4    17.0         8        302.0        140   3449         10.5         70
# ..    ...       ...          ...        ...    ...          ...        ...
# 324  12.0         8        429.0        198   4952         11.5         73
# 325  27.0         4        101.0         83   2202         15.3         76
# 326  17.0         6        250.0        100   3329         15.5         71
# 327  14.5         8        351.0        152   4215         12.8         76
# 328  25.0         6        181.0        110   2945         16.4         82
#
#             origin                          name
# ...

# %%
cars.to_csv('cars_cleaned.csv')
